# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v3

NB_relevant_NB_retraining_v3('task_a_labeled_train.tf', 1000, 0, 'task_a_labeled_tune.tf', 500, 500)
# Out:
# Pre-model is built
# Target-model is built
# 5223
# 42161
# accuracy(no_transfer):  0.914
# accuracy(directly_transfer):  0.452
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.912
# (0.914, 0.452, 0.912)

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v3

NB_relevant_NB_retraining_v3('task_a_labeled_train.tf', 1000, 0, 'task_a_labeled_tune.tf', 500, 500)
# Out:
# Pre-model is built
# Target-model is built
# 5223
# 42161
# accuracy(no_transfer):  0.914
# accuracy(directly_transfer):  0.452
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.916
# (0.914, 0.452, 0.916)

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v3

NB_relevant_NB_retraining_v3('task_a_labeled_train.tf', 1000, 0, 'task_a_labeled_tune.tf', 500, 100)
# Out:
# Pre-model is built
# Target-model is built
# 5223
# 42161
# accuracy(no_transfer):  0.92
# accuracy(directly_transfer):  0.37
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.93
# (0.92, 0.37, 0.93)

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v3

NB_relevant_NB_retraining_v3('task_a_labeled_train.tf', 1000, 0, 'task_a_labeled_tune.tf', 500, 100)
# Out:
# Pre-model is built
# Target-model is built
# 5223
# 42161
# accuracy(no_transfer):  0.92
# accuracy(directly_transfer):  0.37
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.93
# (0.92, 0.37, 0.93)

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v3

NB_relevant_NB_retraining_v3('task_a_labeled_train.tf', 1000, 0, 'task_a_labeled_tune.tf', 500, 100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-4f6264b3cc4a> in <module>
#       1 from NB_Relevance_spam import NB_relevant_NB_retraining_v3
#       2
# ----> 3 NB_relevant_NB_retraining_v3('task_a_labeled_train.tf', 1000, 0, 'task_a_labeled_tune.tf', 500, 100)
#
# c:\Users\rando\OneDrive\Working\transfer learning\NB_Relevance_spam.py in NB_relevant_NB_retraining_v3(training_filename, training_size, testing_size, training_filename_transfer, training_size_transfer, testing_size_transfer)
#     839 def NB_relevant_NB_retraining_v3(training_filename, training_size, testing_size, training_filename_transfer, training_size_transfer, testing_size_transfer):
#     840     # pre-trained model
# --> 841     y1_prob, y0_prob, prior_knowledge, training_data_table, testing_data_table = cal_model(training_filename, training_size, testing_size)
# ...

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v3

NB_relevant_NB_retraining_v3('task_a_labeled_train.tf', 1000, 0, 'task_a_labeled_tune.tf', 100, 100)
# Out:
# Pre-model is built
# Target-model is built
# 2802
# 33553
# accuracy(no_transfer):  0.88
# accuracy(directly_transfer):  0.54
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.81
# (0.88, 0.54, 0.81)

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v3

NB_relevant_NB_retraining_v3('task_a_labeled_train.tf', 1000, 0, 'task_a_labeled_tune.tf', 100, 100)
# Out:
# Pre-model is built
# Target-model is built
# 2802
# 33553
# accuracy(no_transfer):  0.88
# accuracy(directly_transfer):  0.54
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.88
# (0.88, 0.54, 0.88)

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v3

NB_relevant_NB_retraining_v3('task_a_labeled_train.tf', 1000, 0, 'task_a_labeled_tune.tf', 100, 100)
# Out:
# Pre-model is built
# Target-model is built
# 2802
# 33553
# accuracy(no_transfer):  0.88
# accuracy(directly_transfer):  0.54
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.89
# (0.88, 0.54, 0.89)

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v5

NB_relevant_NB_retraining_v5('task_a_labeled_train.tf', 1000, 0, 'task_a_labeled_tune.tf', 1000, 100)
# Out:
# Pre-model is built
# Target-model is built
# 2802
# 33553
# accuracy(no_transfer):  0.88
# accuracy(directly_transfer):  0.54
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.89
# (0.88, 0.54, 0.89)

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v5

NB_relevant_NB_retraining_v5('task_a_labeled_train.tf', 4000, 0, 'task_a_labeled_tune.tf', 1000, 1500)
# Out:
# Pre-model is built
# Target-model is built
# 8073
# 55003
# accuracy(no_transfer):  0.9433333333333334
# accuracy(directly_transfer):  0.5526666666666666
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.952
# (0.9433333333333334, 0.5526666666666666, 0.952)

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v5_progress

error_rate_list = NB_relevant_NB_retraining_v5_progress('task_a_labeled_train.tf', 4000, 0, 'task_a_labeled_tune.tf', 1000, 1500)
# Out:
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.06599999999999995
# 0.05733333333333335
# 0.053333333333333344
# 0.052000000000000046
# 0.052000000000000046
# 0.053333333333333344
# 0.05266666666666664
# 0.05666666666666664
# 0.05666666666666664
# 0.053333333333333344
# 0.05266666666666664
# 0.05266666666666664
# 0.052000000000000046
# 0.052000000000000046
# 0.052000000000000046
# 0.04800000000000004
# 0.04800000000000004
# 0.04800000000000004
# 0.04800000000000004
# 0.04800000000000004
# 0.04800000000000004
# 0.04800000000000004
# 0.04800000000000004
# 0.04800000000000004
# 0.04800000000000004
# 0.04800000000000004
# 0.04800000000000004
# 0.04800000000000004
# 0.04800000000000004
# 0.04800000000000004
# 0.04800000000000004
# Retraining end...

# %%
error_rate_list
# Out:
# [0.44733333333333336,
#  0.048666666666666636,
#  0.06599999999999995,
#  0.05733333333333335,
#  0.053333333333333344,
#  0.052000000000000046,
#  0.052000000000000046,
#  0.053333333333333344,
#  0.05266666666666664,
#  0.05666666666666664,
#  0.05666666666666664,
#  0.053333333333333344,
#  0.05266666666666664,
#  0.05266666666666664,
#  0.052000000000000046,
#  0.052000000000000046,
#  0.052000000000000046,
#  0.04800000000000004,
#  0.04800000000000004,
#  0.04800000000000004,
#  0.04800000000000004,
#  0.04800000000000004,
#  0.04800000000000004,
#  0.04800000000000004,
#  0.04800000000000004,
#  0.04800000000000004,
#  0.04800000000000004,
#  0.04800000000000004,
#  0.04800000000000004,
#  0.04800000000000004,
#  0.04800000000000004,
#  0.04800000000000004,
#  0.04800000000000004]

# %%
from matplotlib import pyplot as plt
x_axis = range(0, len(error_rate_list)*2000, 2000)
plt.plot(x_axis, error_rate_list, label='training,testing')

plt.title('Error Rate in Spam Emails dataset')
plt.xlabel('Fine tuning words')
plt.ylabel('Error Rate')
plt.legend()
plt.show()

# %%
error_rate_list2 = [0.45733333333333337,
 0.17133333333333334,
 0.19999999999999996,
 0.16200000000000003,
 0.14,
 0.1413333333333333,
 0.14,
 0.132,
 0.138,
 0.13866666666666672,
 0.1393333333333333,
 0.1353333333333333,
 0.136,
 0.1353333333333333,
 0.136,
 0.1353333333333333,
 0.1353333333333333,
 0.13666666666666671,
 0.13666666666666671,
 0.13666666666666671,
 0.13666666666666671,
 0.13666666666666671,
 0.13666666666666671,
 0.13666666666666671,
 0.13666666666666671,
 0.13666666666666671]

# %%
error_rate_list3 = [0.46199999999999997,
 0.11199999999999999,
 0.126,
 0.09866666666666668,
 0.09799999999999998,
 0.09666666666666668,
 0.09733333333333338,
 0.09066666666666667,
 0.08733333333333337,
 0.09866666666666668,
 0.09933333333333338,
 0.09399999999999997,
 0.09266666666666667,
 0.09399999999999997,
 0.09399999999999997,
 0.09399999999999997,
 0.09399999999999997,
 0.08466666666666667,
 0.08466666666666667,
 0.08466666666666667,
 0.08466666666666667,
 0.08466666666666667,
 0.08466666666666667,
 0.08466666666666667,
 0.08466666666666667,
 0.08466666666666667,
 0.08466666666666667,
 0.08466666666666667,
 0.08466666666666667,
 0.08466666666666667,
 0.08466666666666667]

# %%
from matplotlib import pyplot as plt
plt.plot(range(0, len(error_rate_list2)*2000, 2000), error_rate_list2, label='training=100')
plt.plot(range(0, len(error_rate_list3)*2000, 2000), error_rate_list3, label='training=500')
plt.plot(range(0, len(error_rate_list)*2000, 2000), error_rate_list, label='training=1000')

plt.title('Error Rate in Spam Emails dataset')
plt.xlabel('Fine tuning words')
plt.ylabel('Error Rate')
plt.legend()
plt.show()

# %%
error_rate_list4 = [0.482,
 0.07799999999999996,
 0.06799999999999995,
 0.08799999999999997,
 0.10733333333333328,
 0.10799999999999998,
 0.10533333333333328,
 0.10599999999999998,
 0.09799999999999998,
 0.10799999999999998,
 0.10666666666666669,
 0.10533333333333328,
 0.10266666666666668,
 0.10199999999999998,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668,
 0.10066666666666668]

# %%
from matplotlib import pyplot as plt
plt.plot(range(0, len(error_rate_list)*2000, 2000), error_rate_list, label='uniformly distributed')
plt.plot(range(0, len(error_rate_list4)*2000, 2000), error_rate_list4, label='skewed')

plt.title('Error Rate in Spam Emails dataset')
plt.xlabel('Fine tuning words')
plt.ylabel('Error Rate')
plt.legend()
plt.show()

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v5
NB_relevant_NB_retraining_v5('task_a_labeled_train.tf', 1000, 0, 'task_a_labeled_tune.tf', 500, 100)
# Out:
# Pre-model is built
# Target-model is built
# 5223
# 42161
# accuracy(no_transfer):  0.92
# accuracy(directly_transfer):  0.37
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.91
# (0.92, 0.37, 0.91)

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v3
NB_relevant_NB_retraining_v3('task_a_labeled_train.tf', 1000, 0, 'task_a_labeled_tune.tf', 0, 100)
# Out:
# Pre-model is built
# Target-model is built
# 0
# 29301
# accuracy(no_transfer):  0.5
# accuracy(directly_transfer):  0.39
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.39
# (0.5, 0.39, 0.39)

# %%
from NB_Relevance_amazon import NB_relevant_NB_retraining_v5
NB_relevant_NB_retraining_v5('Toys_and_Games.json.gz', 1000, 0, 'Patio_Lawn_and_Garden.json.gz', 100, 100)
# Out:
# Pre-model is built
# Target-model is built
# 296
# 4553
# accuracy(no_transfer):  0.56
# accuracy(directly_transfer):  0.62
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.65
# (0.56, 0.62, 0.65)
