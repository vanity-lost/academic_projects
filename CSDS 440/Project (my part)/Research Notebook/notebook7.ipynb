# %%
from NB_Relevance import NB_relevant_NB_retraining_v3, NB_relevant_NB_retraining_v3_analysis, NB_relevant_NB_retraining_v3_analysis_v2

origin_accuracy = []
feature_selection_1_accuracy = []
feature_selection_2_accuracy = []

# %%
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/sci.crypt", "./20news-18828/sci.electronics", 1200, 0, "./20news-18828/sci.med", "./20news-18828/sci.space", 50, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/sci.crypt", "./20news-18828/sci.electronics", 1200, 0, "./20news-18828/sci.med", "./20news-18828/sci.space", 50, 400)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis_v2("./20news-18828/sci.crypt", "./20news-18828/sci.electronics", 1200, 0, "./20news-18828/sci.med", "./20news-18828/sci.space", 50, 400)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)

accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/comp.windows.x", "./20news-18828/comp.sys.mac.hardware", 50, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/comp.windows.x", "./20news-18828/comp.sys.mac.hardware", 50, 400)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis_v2("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/comp.windows.x", "./20news-18828/comp.sys.mac.hardware", 50, 400)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)

accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/sci.electronics", "./20news-18828/sci.med", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/talk.religion.misc", 50, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/sci.electronics", "./20news-18828/sci.med", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/talk.religion.misc", 50, 400)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis_v2("./20news-18828/sci.electronics", "./20news-18828/sci.med", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/talk.religion.misc", 50, 400)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)

accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/talk.politics.guns", "./20news-18828/talk.politics.mideast", 1200, 0, "./20news-18828/comp.graphics", "./20news-18828/comp.sys.ibm.pc.hardware", 50, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/talk.politics.guns", "./20news-18828/talk.politics.mideast", 1200, 0, "./20news-18828/comp.graphics", "./20news-18828/comp.sys.ibm.pc.hardware", 50, 400)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis_v2("./20news-18828/talk.politics.guns", "./20news-18828/talk.politics.mideast", 1200, 0, "./20news-18828/comp.graphics", "./20news-18828/comp.sys.ibm.pc.hardware", 50, 400)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)

accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/misc.forsale", 50, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/misc.forsale", 50, 400)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis_v2("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/misc.forsale", 50, 400)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)

accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/rec.autos", "./20news-18828/rec.motorcycles", 1200, 0, "./20news-18828/sci.electronics", "./20news-18828/sci.med", 50, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/rec.autos", "./20news-18828/rec.motorcycles", 1200, 0, "./20news-18828/sci.electronics", "./20news-18828/sci.med", 50, 400)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis_v2("./20news-18828/rec.autos", "./20news-18828/rec.motorcycles", 1200, 0, "./20news-18828/sci.electronics", "./20news-18828/sci.med", 50, 400)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)
# Out:
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8575
# accuracy(directly_transfer):  0.5975
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.815
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8575
# accuracy(directly_transfer):  0.55
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.835
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8
# accuracy(directly_transfer):  0.535
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.8875
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8
# accuracy(directly_transfer):  0.57
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.835
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8925
# accuracy(directly_transfer):  0.59
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.905
# Pre-model is built
# ...

# %%
from matplotlib import pyplot as plt
x = ['sci,sci', 'comp,comp', 'sci,talk', 'talk,comp', 'comp,mixed', 'rec,sci']
plt.plot(x, origin_accuracy, label='origin')
plt.plot(x, feature_selection_accuracy, label='feature selected')

plt.title('Comparasion of whether use feature selection (20News)')
plt.title('Comparasion of whether use feature selection (20News)')
plt.xlabel('Datasets')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from NB_Relevance import NB_relevant_NB_retraining_v3

large_accuracy2 = []
small_accuracy2 = []

# %%
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/sci.crypt", "./20news-18828/sci.electronics", 1200, 0, "./20news-18828/sci.med", "./20news-18828/sci.space", 800, 400)
large_accuracy2.append(accuracy_relevant_transfer-accuracy_original)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/sci.crypt", "./20news-18828/sci.electronics", 1200, 0, "./20news-18828/sci.med", "./20news-18828/sci.space", 50, 400)
small_accuracy2.append(accuracy_relevant_transfer-accuracy_original)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/comp.windows.x", "./20news-18828/comp.sys.mac.hardware", 800, 400)
large_accuracy2.append(accuracy_relevant_transfer-accuracy_original)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/comp.windows.x", "./20news-18828/comp.sys.mac.hardware", 50, 400)
small_accuracy2.append(accuracy_relevant_transfer-accuracy_original)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/sci.electronics", "./20news-18828/sci.med", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/talk.religion.misc", 800, 400)
large_accuracy2.append(accuracy_relevant_transfer-accuracy_original)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/sci.electronics", "./20news-18828/sci.med", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/talk.religion.misc", 50, 400)
small_accuracy2.append(accuracy_relevant_transfer-accuracy_original)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/talk.politics.guns", "./20news-18828/talk.politics.mideast", 1200, 0, "./20news-18828/comp.graphics", "./20news-18828/comp.sys.ibm.pc.hardware", 800, 400)
large_accuracy2.append(accuracy_relevant_transfer-accuracy_original)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/talk.politics.guns", "./20news-18828/talk.politics.mideast", 1200, 0, "./20news-18828/comp.graphics", "./20news-18828/comp.sys.ibm.pc.hardware", 50, 400)
small_accuracy2.append(accuracy_relevant_transfer-accuracy_original)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/misc.forsale", 800, 400)
large_accuracy2.append(accuracy_relevant_transfer-accuracy_original)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/misc.forsale", 50, 400)
small_accuracy2.append(accuracy_relevant_transfer-accuracy_original)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/rec.autos", "./20news-18828/rec.motorcycles", 1200, 0, "./20news-18828/sci.electronics", "./20news-18828/sci.med", 800, 400)
large_accuracy2.append(accuracy_relevant_transfer-accuracy_original)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/rec.autos", "./20news-18828/rec.motorcycles", 1200, 0, "./20news-18828/sci.electronics", "./20news-18828/sci.med", 50, 400)
small_accuracy2.append(accuracy_relevant_transfer-accuracy_original)
# Out:
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.985
# accuracy(directly_transfer):  0.555
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.985
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8575
# accuracy(directly_transfer):  0.5975
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.815
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.9775
# accuracy(directly_transfer):  0.5075
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.965
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8
# accuracy(directly_transfer):  0.535
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.8875
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.965
# accuracy(directly_transfer):  0.595
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.96
# Pre-model is built
# ...

# %%
from NB_Relevance_amazon import NB_relevant_NB_retraining_v3_progress

error_rate_list = NB_relevant_NB_retraining_v3_progress(10000, 0, 10000, 50000)

# %%
from NB_Relevance_amazon import NB_relevant_NB_retraining_v3, NB_relevant_NB_retraining_v3_analysis

origin_accuracy = []
feature_selection_accuracy = []

# %%
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3('Toys_and_Games.json.gz', 10000, 0, 'Patio_Lawn_and_Garden.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis('Toys_and_Games.json.gz', 10000, 0, 'Patio_Lawn_and_Garden.json.gz', 5000, 5000)
feature_selection_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3('Video_Games.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis('Video_Games.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
feature_selection_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3('Electronics.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis('Electronics.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
feature_selection_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3('Software.json.gz', 10000, 0, 'Video_Games.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis('Software.json.gz', 10000, 0, 'Video_Games.json.gz', 5000, 5000)
feature_selection_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3('Toys_and_Games.json.gz', 10000, 0, 'Software.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis('Toys_and_Games.json.gz', 10000, 0, 'Software.json.gz', 5000, 5000)
feature_selection_accuracy.append(accuracy_relevant_transfer)
# Out:
# Pre-model is built
# Target-model is built
# 6559
# 12532
# accuracy(no_transfer):  0.769
# accuracy(directly_transfer):  0.6876
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7696
# Pre-model is built
# Target-model is built
# 2970
# 796
# accuracy(no_transfer):  0.769
# accuracy(directly_transfer):  0.6794
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7696
# Pre-model is built
# Target-model is built
# 8159
# 18769
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.8804
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.9172
# Pre-model is built
# Target-model is built
# 3403
# 1134
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.885
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.9184
# Pre-model is built
# Target-model is built
# 7687
# 15149
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.8546
# Retraining start...
# ...

# %%
from matplotlib import pyplot as plt
x = ['pair 1', 'pair 2', 'pair 3', 'pair 4', 'pair 5']
plt.plot(x, origin_accuracy, label='origin')
plt.plot(x, feature_selection_accuracy, label='feature selected')

plt.title('Comparasion of whether use feature selection (Amazon Review)')
plt.xlabel('Datasets')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from NB_Relevance_amazon import NB_relevant_NB_retraining_v5, NB_relevant_NB_retraining_v5_fs_1, NB_relevant_NB_retraining_v5_fs_2

origin_accuracy = []
feature_selection_1_accuracy = []
feature_selection_2_accuracy = []

# %%
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5('Toys_and_Games.json.gz', 10000, 0, 'Patio_Lawn_and_Garden.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5_fs_1('Toys_and_Games.json.gz', 10000, 0, 'Patio_Lawn_and_Garden.json.gz', 5000, 5000)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5_fs_2('Toys_and_Games.json.gz', 10000, 0, 'Patio_Lawn_and_Garden.json.gz', 5000, 5000)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)

accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5('Video_Games.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5_fs_1('Video_Games.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5_fs_2('Video_Games.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)
# Out:
# Pre-model is built
# Target-model is built
# 6559
# 12532
# accuracy(no_transfer):  0.769
# accuracy(directly_transfer):  0.6876
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.6912
# Pre-model is built
# Target-model is built
# 2970
# 8223
# accuracy(no_transfer):  0.769
# accuracy(directly_transfer):  0.6794
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.669
# Pre-model is built
# Target-model is built
# 3589
# 14706
# accuracy(no_transfer):  0.769
# accuracy(directly_transfer):  0.5866
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.77
# Pre-model is built
# Target-model is built
# 8159
# 18769
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.8804
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.909
# Pre-model is built
# Target-model is built
# 3403
# 9436
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.885
# Retraining start...
# ...

# %%
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5('Electronics.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5_fs_1('Electronics.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5_fs_2('Electronics.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)

accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5('Software.json.gz', 10000, 0, 'Video_Games.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5_fs_1('Software.json.gz', 10000, 0, 'Video_Games.json.gz', 5000, 5000)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5_fs_2('Software.json.gz', 10000, 0, 'Video_Games.json.gz', 5000, 5000)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)
# Out:
# Pre-model is built
# Target-model is built
# 7687
# 15149
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.8546
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.8908
# Pre-model is built
# Target-model is built
# 3219
# 9511
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.8524
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.872
# Pre-model is built
# Target-model is built
# 4468
# 17343
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.5802
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.9244
# Pre-model is built
# Target-model is built
# 9743
# 21344
# accuracy(no_transfer):  0.788
# accuracy(directly_transfer):  0.732
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7682
# Pre-model is built
# Target-model is built
# 4253
# 12581
# accuracy(no_transfer):  0.788
# accuracy(directly_transfer):  0.756
# Retraining start...
# ...

# %%
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5('Toys_and_Games.json.gz', 10000, 0, 'Software.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5_fs_1('Toys_and_Games.json.gz', 10000, 0, 'Software.json.gz', 5000, 5000)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5_fs_2('Toys_and_Games.json.gz', 10000, 0, 'Software.json.gz', 5000, 5000)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)
# Out:
# Pre-model is built
# Target-model is built
# 8188
# 15041
# accuracy(no_transfer):  0.699
# accuracy(directly_transfer):  0.6842
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.678
# Pre-model is built
# Target-model is built
# 3188
# 13554
# accuracy(no_transfer):  0.699
# accuracy(directly_transfer):  0.6664
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.6552
# Pre-model is built
# Target-model is built
# 5000
# 17651
# accuracy(no_transfer):  0.699
# accuracy(directly_transfer):  0.5684
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7214

# %%
from matplotlib import pyplot as plt
x = ['pair 1', 'pair 2', 'pair 3', 'pair 4', 'pair 5']
plt.plot(x, origin_accuracy, label='origin')
plt.plot(x, feature_selection_1_accuracy, label='Remove Relevant')
plt.plot(x, feature_selection_2_accuracy, label='Remove nonrelevant')

plt.title('Comparasion of whether use feature selection (Amazon Review)')
plt.xlabel('Datasets')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from NB_Relevance_amazon import NB_relevant_NB_retraining_v3, NB_relevant_NB_retraining_v3_fs_1, NB_relevant_NB_retraining_v3_fs_2

origin_accuracy = []
feature_selection_1_accuracy = []
feature_selection_2_accuracy = []

# %%
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3('Toys_and_Games.json.gz', 10000, 0, 'Patio_Lawn_and_Garden.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_fs_1('Toys_and_Games.json.gz', 10000, 0, 'Patio_Lawn_and_Garden.json.gz', 5000, 5000)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_fs_2('Toys_and_Games.json.gz', 10000, 0, 'Patio_Lawn_and_Garden.json.gz', 5000, 5000)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)

accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3('Video_Games.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_fs_1('Video_Games.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_fs_2('Video_Games.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)
# Out:
# Pre-model is built
# Target-model is built
# 6559
# 12532
# accuracy(no_transfer):  0.769
# accuracy(directly_transfer):  0.6876
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7696
# Pre-model is built
# Target-model is built
# 1025
# 186
# accuracy(no_transfer):  0.769
# accuracy(directly_transfer):  0.6434
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7702
# Pre-model is built
# Target-model is built
# 5534
# 8508
# accuracy(no_transfer):  0.769
# accuracy(directly_transfer):  0.6256
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7682
# Pre-model is built
# Target-model is built
# 8159
# 18769
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.8804
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.9172
# Pre-model is built
# Target-model is built
# 751
# 187
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.8376
# Retraining start...
# ...

# %%
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3('Electronics.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_fs_1('Electronics.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_fs_2('Electronics.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)

accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3('Software.json.gz', 10000, 0, 'Video_Games.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_fs_1('Software.json.gz', 10000, 0, 'Video_Games.json.gz', 5000, 5000)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_fs_2('Software.json.gz', 10000, 0, 'Video_Games.json.gz', 5000, 5000)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)
# Out:
# Pre-model is built
# Target-model is built
# 7687
# 15149
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.8546
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.9202
# Pre-model is built
# Target-model is built
# 859
# 228
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.8564
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.92
# Pre-model is built
# Target-model is built
# 6828
# 10903
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.554
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.9202
# Pre-model is built
# Target-model is built
# 9743
# 21344
# accuracy(no_transfer):  0.788
# accuracy(directly_transfer):  0.732
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7878
# Pre-model is built
# Target-model is built
# 1174
# 239
# accuracy(no_transfer):  0.788
# accuracy(directly_transfer):  0.8068
# Retraining start...
# ...

# %%
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3('Toys_and_Games.json.gz', 10000, 0, 'Software.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_fs_1('Toys_and_Games.json.gz', 10000, 0, 'Software.json.gz', 5000, 5000)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_fs_2('Toys_and_Games.json.gz', 10000, 0, 'Software.json.gz', 5000, 5000)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)
# Out:
# Pre-model is built
# Target-model is built
# 8188
# 15041
# accuracy(no_transfer):  0.699
# accuracy(directly_transfer):  0.6842
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7022
# Pre-model is built
# Target-model is built
# 1074
# 137
# accuracy(no_transfer):  0.699
# accuracy(directly_transfer):  0.6192
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7004
# Pre-model is built
# Target-model is built
# 7114
# 6928
# accuracy(no_transfer):  0.699
# accuracy(directly_transfer):  0.642
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7002

# %%
from matplotlib import pyplot as plt
x = ['pair 1', 'pair 2', 'pair 3', 'pair 4', 'pair 5']
plt.plot(x, origin_accuracy, label='origin')
plt.plot(x, feature_selection_1_accuracy, label='Remove Irrelevant word')
plt.plot(x, feature_selection_2_accuracy, label='Remove Relevant word')

plt.title('Comparasion of whether use feature selection (Amazon Review)')
plt.xlabel('Datasets')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
origin_accuracy
# Out:
# [0.7696, 0.9172, 0.9202, 0.7878, 0.7022]

# %%
feature_selection_1_accuracy
# Out:
# [0.7702, 0.9188, 0.92, 0.7852, 0.7004]

# %%
feature_selection_2_accuracy
# Out:
# [0.7682, 0.9178, 0.9202, 0.7896, 0.7002]
