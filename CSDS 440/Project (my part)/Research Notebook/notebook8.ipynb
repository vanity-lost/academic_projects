# %%
from NB_Relevance import NB_relevant_NB_retraining_v3, NB_relevant_NB_retraining_v3_analysis

origin_accuracy = []
feature_selection_accuracy = []

# %%
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/sci.crypt", "./20news-18828/sci.electronics", 1200, 0, "./20news-18828/sci.med", "./20news-18828/sci.space", 800, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/sci.crypt", "./20news-18828/sci.electronics", 1200, 0, "./20news-18828/sci.med", "./20news-18828/sci.space", 800, 400)
feature_selection_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/comp.windows.x", "./20news-18828/comp.sys.mac.hardware", 800, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/comp.windows.x", "./20news-18828/comp.sys.mac.hardware", 800, 400)
feature_selection_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/sci.electronics", "./20news-18828/sci.med", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/talk.religion.misc", 800, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/sci.electronics", "./20news-18828/sci.med", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/talk.religion.misc", 800, 400)
feature_selection_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/talk.politics.guns", "./20news-18828/talk.politics.mideast", 1200, 0, "./20news-18828/comp.graphics", "./20news-18828/comp.sys.ibm.pc.hardware", 800, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/talk.politics.guns", "./20news-18828/talk.politics.mideast", 1200, 0, "./20news-18828/comp.graphics", "./20news-18828/comp.sys.ibm.pc.hardware", 800, 400)
feature_selection_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/misc.forsale", 800, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/misc.forsale", 800, 400)
feature_selection_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/rec.autos", "./20news-18828/rec.motorcycles", 1200, 0, "./20news-18828/sci.electronics", "./20news-18828/sci.med", 800, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/rec.autos", "./20news-18828/rec.motorcycles", 1200, 0, "./20news-18828/sci.electronics", "./20news-18828/sci.med", 800, 400)
feature_selection_accuracy.append(accuracy_relevant_transfer)
# Out:
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.985
# accuracy(directly_transfer):  0.555
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.985
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.985
# accuracy(directly_transfer):  0.515
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.985
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.9775
# accuracy(directly_transfer):  0.5075
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.965
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.9775
# accuracy(directly_transfer):  0.5475
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.97
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.965
# accuracy(directly_transfer):  0.595
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.96
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.965
# accuracy(directly_transfer):  0.535
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.96
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.945
# accuracy(directly_transfer):  0.4775
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.94
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.945
# accuracy(directly_transfer):  0.475
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.9425
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.975
# accuracy(directly_transfer):  0.5025
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.9775
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.975
# accuracy(directly_transfer):  0.485
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.975
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.9825
# accuracy(directly_transfer):  0.565
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.9875
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.9825
# accuracy(directly_transfer):  0.56
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.9875

# %%
from matplotlib import pyplot as plt
x = ['sci,sci', 'comp,comp', 'sci,talk', 'talk,comp', 'comp,mixed', 'rec,sci']
plt.plot(x, origin_accuracy, label='origin')
plt.plot(x, feature_selection_accuracy, label='feature selected')

plt.title('Comparasion of whether use feature selection (20News)')
plt.title('Comparasion of whether use feature selection (20News)')
plt.xlabel('Datasets')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from NB_Relevance_amazon import NB_relevant_NB_retraining_v3_progress

error_rate_list = NB_relevant_NB_retraining_v3_progress(50000, 0, 10000, 20000)

# %%
from NB_Relevance_amazon import NB_relevant_NB_retraining_v3_progress
error_rate_list1 = NB_relevant_NB_retraining_v3_progress('Toys_and_Games.json.gz', 5000, 0, 'Patio_Lawn_and_Garden.json.gz', 5000, 2000)
# Out:
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.16800000000000004
# 0.16649999999999998
# 0.16549999999999998
# 0.16500000000000004
# 0.16449999999999998
# 0.16549999999999998
# 0.16549999999999998
# Retraining end...

# %%
from NB_Relevance_amazon import NB_relevant_NB_retraining_v3_progress
error_rate_list2 = NB_relevant_NB_retraining_v3_progress('Video_Games.json.gz', 5000, 0, 'Toys_and_Games.json.gz', 1000, 2000)
# Out:
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.33199999999999996
# 0.33599999999999997
# 0.33299999999999996
# 0.3335
# 0.33299999999999996
# 0.3315
# 0.33199999999999996
# 0.33299999999999996
# 0.33299999999999996
# Retraining end...

# %%
from NB_Relevance_amazon import NB_relevant_NB_retraining_v3_progress
error_rate_list3 = NB_relevant_NB_retraining_v3_progress('Electronics.json.gz', 5000, 0, 'Cell_Phones_and_Accessories.json.gz', 1000, 2000)
# Out:
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.24450000000000005
# 0.244
# 0.23299999999999998
# 0.23050000000000004
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-73e86393696c> in <module>
#       1 from NB_Relevance_amazon import NB_relevant_NB_retraining_v3_progress
# ----> 2 error_rate_list3 = NB_relevant_NB_retraining_v3_progress('Electronics.json.gz', 5000, 0, 'Cell_Phones_and_Accessories.json.gz', 1000, 2000)
#
# c:\Users\rando\OneDrive\Working\transfer learning\NB_Relevance_amazon.py in NB_relevant_NB_retraining_v3_progress(training_filename, training_size, testing_size, training_filename_transfer, training_size_transfer, testing_size_transfer)
#     615             prior_knowledge[word] = [probX_Y1 * 0.9, probX_Y0 * 0.9]
#     616         if count % 2000 == 0:
# --> 617             accuracy_relevant_transfer = cal_direct_accuracy(testing_data_table_transfer, y1_prob_transfer, y0_prob_transfer, prior_knowledge)
#     618             error_rate_list.append(1-accuracy_relevant_transfer)
#     619             count = 0
#
# c:\Users\rando\OneDrive\Working\transfer learning\NB_Relevance_amazon.py in cal_direct_accuracy(testing_data_table_transfer, y1_prob, y0_prob, prior_knowledge)
#     128             if testing_data_table_transfer[0][j] in prior_knowledge.keys():
#     129                 [probX_Y1, probX_Y0] = prior_knowledge[testing_data_table_transfer[0][j]]
# --> 130                 prob_Y1 += np.log(probX_Y1) * testing_data_table_transfer[i][j]
#     131                 prob_Y0 += np.log(probX_Y0) * testing_data_table_transfer[i][j]
#     132         predicted_class_label = 1 if prob_Y1 >= prob_Y0 else 0
#
# KeyboardInterrupt:

# %%
from NB_Relevance_amazon import NB_relevant_NB_retraining_v3_progress
error_rate_list4 = NB_relevant_NB_retraining_v3_progress('Electronics.json.gz', 5000, 0, 'Toys_and_Games.json.gz', 1000, 2000)

# %%
from NB_Relevance_amazon import NB_relevant_NB_retraining_v3_progress
error_rate_list5 = NB_relevant_NB_retraining_v3_progress('Electronics.json.gz', 5000, 0, 'Patio_Lawn_and_Garden.json.gz', 1000, 2000)

# %%
from NB_Relevance_amazon import NB_relevant_NB_retraining_v3

no_transfer = [0] * 5
transfered = [0] * 5
no_transfer[0], acc, transfered[0] = NB_relevant_NB_retraining_v3('Toys_and_Games.json.gz', 10000, 0, 'Patio_Lawn_and_Garden.json.gz', 5000, 5000)
no_transfer[1], acc, transfered[1] = NB_relevant_NB_retraining_v3('Video_Games.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
no_transfer[2], acc, transfered[2] = NB_relevant_NB_retraining_v3('Cell_Phones_and_Accessories.json.gz', 10000, 0, 'Electronics.json.gz', 5000, 5000)
no_transfer[3], acc, transfered[3] = NB_relevant_NB_retraining_v3('Electronics.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
no_transfer[4], acc, transfered[4] = NB_relevant_NB_retraining_v3('Patio_Lawn_and_Garden.json.gz', 10000, 0, 'Electronics.json.gz', 5000, 5000)
# Out:
# Pre-model is built
# Target-model is built
# 6559
# 12532
# accuracy(no_transfer):  0.769
# accuracy(directly_transfer):  0.6876
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7678
# Pre-model is built
# Target-model is built
# 8159
# 18769
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.8804
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.9006
# Pre-model is built
# Target-model is built
# 7946
# 14735
# accuracy(no_transfer):  0.737
# accuracy(directly_transfer):  0.8678
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7244
# Pre-model is built
# Target-model is built
# 7687
# 15149
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.8546
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.8978
# Pre-model is built
# Target-model is built
# 7062
# 13840
# accuracy(no_transfer):  0.737
# accuracy(directly_transfer):  0.8288
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.74

# %%
from matplotlib import pyplot as plt
x_axis = ['pair1', 'pair2', 'pair3', 'pair4', 'pair5']
plt.plot(x_axis, no_transfer, label='learning without transfer')
plt.plot(x_axis, transfered, label='learning with transfer')

plt.title('Error Rate in Amazon dataset (Different distribution)')
plt.xlabel('Fine tuning words')
plt.ylabel('Error Rate')
plt.legend()
plt.show()

# %%
from NB_Relevance_amazon import NB_relevant_NB_retraining_v3_progress

error_rate_list = []
error_rate_list.append(NB_relevant_NB_retraining_v3_progress('Toys_and_Games.json.gz', 10000, 0, 'Patio_Lawn_and_Garden.json.gz', 5000, 5000))
error_rate_list.append(NB_relevant_NB_retraining_v3_progress('Video_Games.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000))
error_rate_list.append(NB_relevant_NB_retraining_v3_progress('Electronics.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000))
error_rate_list.append(NB_relevant_NB_retraining_v3_progress('Software.json.gz', 10000, 0, 'Video_Games.json.gz', 5000, 5000))
error_rate_list.append(NB_relevant_NB_retraining_v3_progress('Toys_and_Games.json.gz', 10000, 0, 'Software.json.gz', 5000, 5000))
# Out:
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.2548
# 0.24639999999999995
# 0.25
# 0.24739999999999995
# 0.24280000000000002
# 0.23939999999999995
# 0.23399999999999999
# 0.23040000000000005
# 0.23040000000000005
# Retraining end...
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.0756
# 0.0776
# 0.07779999999999998
# 0.08140000000000003
# 0.07979999999999998
# 0.08040000000000003
# 0.08140000000000003
# 0.08199999999999996
# 0.08079999999999998
# 0.0816
# 0.08240000000000003
# 0.08279999999999998
# 0.08279999999999998
# Retraining end...
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.1058
# 0.08199999999999996
# 0.08340000000000003
# 0.07940000000000003
# 0.0766
# 0.07820000000000005
# 0.0786
# 0.0776
# 0.07920000000000005
# 0.07979999999999998
# 0.07979999999999998
# Retraining end...
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.1976
# 0.17400000000000004
# 0.18500000000000005
# 0.18820000000000003
# 0.1894
# 0.19679999999999997
# 0.1996
# 0.19840000000000002
# 0.2138
# 0.21399999999999997
# 0.2138
# 0.2136
# 0.21220000000000006
# 0.21220000000000006
# 0.21220000000000006
# Retraining end...
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.3224
# 0.3214
# 0.3304
# 0.33140000000000003
# 0.3206
# 0.30079999999999996
# 0.29900000000000004
# 0.29779999999999995
# 0.29779999999999995
# 0.29779999999999995
# 0.29779999999999995
# Retraining end...

# %%
from matplotlib import pyplot as plt
plt.plot(range(0, len(error_rate_list[0])*2000, 2000), error_rate_list[0], label='pair1')
plt.plot(range(0, len(error_rate_list[1])*2000, 2000), error_rate_list[1], label='pair2')
plt.plot(range(0, len(error_rate_list[2])*2000, 2000), error_rate_list[2], label='pair3')
plt.plot(range(0, len(error_rate_list[3])*2000, 2000), error_rate_list[3], label='pair4')
plt.plot(range(0, len(error_rate_list[4])*2000, 2000), error_rate_list[4], label='pair5')

plt.title('Error Rate in Amazon dataset')
plt.xlabel('Fine tuning words')
plt.ylabel('Error Rate')
plt.legend()
plt.show()

# %%
from NB_Relevance_amazon import NB_relevant_NB_retraining_v5_progress

error_rate_list3 = NB_relevant_NB_retraining_v5_progress('Electronics.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
error_rate_list4 = NB_relevant_NB_retraining_v5_progress('Software.json.gz', 10000, 0, 'Video_Games.json.gz', 5000, 5000)
# Out:
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.118
# 0.09560000000000002
# 0.09319999999999995
# 0.08960000000000001
# 0.08320000000000005
# 0.0826
# 0.08279999999999998
# 0.08320000000000005
# 0.08499999999999996
# 0.08660000000000001
# 0.08660000000000001
# Retraining end...
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.268
# 0.25739999999999996
# 0.2592
# 0.257
# 0.25260000000000005
# 0.2398
# 0.23419999999999996
# 0.23260000000000003
# 0.2338
# 0.23419999999999996
# 0.23460000000000003
# 0.23560000000000003
# 0.2358
# 0.2358
# 0.2358
# Retraining end...

# %%
error_rate_list3
# Out:
# [0.14539999999999997,
#  0.14400000000000002,
#  0.118,
#  0.09560000000000002,
#  0.09319999999999995,
#  0.08960000000000001,
#  0.08320000000000005,
#  0.0826,
#  0.08279999999999998,
#  0.08320000000000005,
#  0.08499999999999996,
#  0.08660000000000001,
#  0.08660000000000001]

# %%
error_rate_list4
# Out:
# [0.268,
#  0.26160000000000005,
#  0.268,
#  0.25739999999999996,
#  0.2592,
#  0.257,
#  0.25260000000000005,
#  0.2398,
#  0.23419999999999996,
#  0.23260000000000003,
#  0.2338,
#  0.23419999999999996,
#  0.23460000000000003,
#  0.23560000000000003,
#  0.2358,
#  0.2358,
#  0.2358]

# %%
from NB_Relevance import NB_relevant_NB_retraining_v3, NB_relevant_NB_retraining_v3_analysis, NB_relevant_NB_retraining_v3_analysis_v2

origin_accuracy = []
feature_selection_1_accuracy = []
feature_selection_2_accuracy = []

# %%
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/sci.crypt", "./20news-18828/sci.electronics", 1200, 0, "./20news-18828/sci.med", "./20news-18828/sci.space", 50, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/sci.crypt", "./20news-18828/sci.electronics", 1200, 0, "./20news-18828/sci.med", "./20news-18828/sci.space", 50, 400)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis_v2("./20news-18828/sci.crypt", "./20news-18828/sci.electronics", 1200, 0, "./20news-18828/sci.med", "./20news-18828/sci.space", 50, 400)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)

accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/comp.windows.x", "./20news-18828/comp.sys.mac.hardware", 50, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/comp.windows.x", "./20news-18828/comp.sys.mac.hardware", 50, 400)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis_v2("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/comp.windows.x", "./20news-18828/comp.sys.mac.hardware", 50, 400)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)

accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/sci.electronics", "./20news-18828/sci.med", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/talk.religion.misc", 50, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/sci.electronics", "./20news-18828/sci.med", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/talk.religion.misc", 50, 400)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis_v2("./20news-18828/sci.electronics", "./20news-18828/sci.med", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/talk.religion.misc", 50, 400)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)

accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/talk.politics.guns", "./20news-18828/talk.politics.mideast", 1200, 0, "./20news-18828/comp.graphics", "./20news-18828/comp.sys.ibm.pc.hardware", 50, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/talk.politics.guns", "./20news-18828/talk.politics.mideast", 1200, 0, "./20news-18828/comp.graphics", "./20news-18828/comp.sys.ibm.pc.hardware", 50, 400)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis_v2("./20news-18828/talk.politics.guns", "./20news-18828/talk.politics.mideast", 1200, 0, "./20news-18828/comp.graphics", "./20news-18828/comp.sys.ibm.pc.hardware", 50, 400)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)

accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/misc.forsale", 50, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/misc.forsale", 50, 400)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis_v2("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/talk.politics.guns", "./20news-18828/misc.forsale", 50, 400)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)

accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3("./20news-18828/rec.autos", "./20news-18828/rec.motorcycles", 1200, 0, "./20news-18828/sci.electronics", "./20news-18828/sci.med", 50, 400)
origin_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis("./20news-18828/rec.autos", "./20news-18828/rec.motorcycles", 1200, 0, "./20news-18828/sci.electronics", "./20news-18828/sci.med", 50, 400)
feature_selection_1_accuracy.append(accuracy_relevant_transfer)
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v3_analysis_v2("./20news-18828/rec.autos", "./20news-18828/rec.motorcycles", 1200, 0, "./20news-18828/sci.electronics", "./20news-18828/sci.med", 50, 400)
feature_selection_2_accuracy.append(accuracy_relevant_transfer)
# Out:
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8575
# accuracy(directly_transfer):  0.5975
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.815
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8575
# accuracy(directly_transfer):  0.54
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.8525
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8575
# accuracy(directly_transfer):  0.5025
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.805
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8
# accuracy(directly_transfer):  0.535
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.8875
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8
# accuracy(directly_transfer):  0.7775
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.815
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8
# accuracy(directly_transfer):  0.5
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.8825
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8925
# accuracy(directly_transfer):  0.59
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.905
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8925
# accuracy(directly_transfer):  0.5225
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.8975
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8925
# accuracy(directly_transfer):  0.605
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.8975
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8075
# accuracy(directly_transfer):  0.4775
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7525
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8075
# accuracy(directly_transfer):  0.4325
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7525
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8075
# accuracy(directly_transfer):  0.505
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.795
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8725
# accuracy(directly_transfer):  0.4975
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.9075
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8725
# accuracy(directly_transfer):  0.44
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.8675
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.8725
# accuracy(directly_transfer):  0.5
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.91
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.6975
# accuracy(directly_transfer):  0.555
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7075
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.6975
# accuracy(directly_transfer):  0.525
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.685
# Pre-model is built
# Target-model is built
# accuracy(no_transfer):  0.6975
# accuracy(directly_transfer):  0.545
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.7125

# %%
from matplotlib import pyplot as plt
x = ['sci,sci', 'comp,comp', 'sci,talk', 'talk,comp', 'comp,mixed', 'rec,sci']
plt.plot(x, origin_accuracy, label='origin')
plt.plot(x, feature_selection_1_accuracy, label='Remove irrelevant word')
plt.plot(x, feature_selection_2_accuracy, label='Remove relevant word')

plt.title('Comparasion of whether use feature selection (20News)')
plt.xlabel('Datasets')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
