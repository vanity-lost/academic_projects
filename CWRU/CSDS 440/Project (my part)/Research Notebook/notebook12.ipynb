# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v3

NB_relevant_NB_retraining_v3('task_a_labeled_train.tf', 4000, 0, 'task_a_labeled_tune.tf', 1000, 1500)
# Out:
# Pre-model is built
# Target-model is built
# 8073
# 55003
# accuracy(no_transfer):  0.9433333333333334
# accuracy(directly_transfer):  0.5526666666666666
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.9446666666666667
# (0.9433333333333334, 0.5526666666666666, 0.9446666666666667)

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v3_progress
error_rate_list = NB_relevant_NB_retraining_v3_progress('task_a_labeled_train.tf', 4000, 0, 'task_a_labeled_tune.tf', 1000, 1500)
# Out:
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.04733333333333334
# 0.043333333333333335
# 0.04800000000000004
# 0.050000000000000044
# 0.050000000000000044
# 0.05266666666666664
# 0.05666666666666664
# 0.062000000000000055
# 0.06266666666666665
# 0.06066666666666665
# 0.06066666666666665
# 0.06000000000000005
# 0.06399999999999995
# 0.06799999999999995
# 0.07266666666666666
# 0.06333333333333335
# 0.06333333333333335
# 0.06466666666666665
# 0.06599999999999995
# 0.058666666666666645
# 0.055333333333333345
# 0.055333333333333345
# 0.055333333333333345
# 0.055333333333333345
# 0.055333333333333345
# 0.055333333333333345
# 0.055333333333333345
# 0.055333333333333345
# 0.055333333333333345
# 0.055333333333333345
# 0.055333333333333345
# Retraining end...

# %%
from matplotlib import pyplot as plt
x_axis = range(0, len(error_rate_list)*2000, 2000)
plt.plot(x_axis, error_rate_list, label='training,testing')

plt.title('Error Rate in Spam Emails dataset')
plt.xlabel('Fine tuning words')
plt.ylabel('Error Rate')
plt.legend()
plt.show()

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v3_progress
error_rate_list2 = NB_relevant_NB_retraining_v3_progress('task_a_labeled_train.tf', 4000, 0, 'task_a_labeled_tune.tf', 100, 1500)
# Out:
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.19666666666666666
# 0.14466666666666672
# 0.1333333333333333
# 0.1286666666666667
# 0.1246666666666667
# 0.1206666666666667
# 0.11533333333333329
# 0.11333333333333329
# 0.11133333333333328
# 0.11266666666666669
# 0.11399999999999999
# 0.11199999999999999
# 0.10999999999999999
# 0.10866666666666669
# 0.10866666666666669
# 0.10999999999999999
# 0.11066666666666669
# 0.11199999999999999
# 0.11399999999999999
# 0.11399999999999999
# 0.1166666666666667
# 0.1166666666666667
# 0.1166666666666667
# 0.1166666666666667
# Retraining end...

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v3_progress
error_rate_list3 = NB_relevant_NB_retraining_v3_progress('task_a_labeled_train.tf', 4000, 0, 'task_a_labeled_tune.tf', 500, 1500)
# Out:
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.10866666666666669
# 0.07933333333333337
# 0.06999999999999995
# 0.07199999999999995
# 0.07133333333333336
# 0.07933333333333337
# 0.07999999999999996
# 0.08733333333333337
# 0.08666666666666667
# 0.08466666666666667
# 0.08466666666666667
# 0.08799999999999997
# 0.08866666666666667
# 0.09733333333333338
# 0.09533333333333338
# 0.08933333333333338
# 0.08933333333333338
# 0.08799999999999997
# 0.08733333333333337
# 0.08066666666666666
# 0.07599999999999996
# 0.07599999999999996
# 0.07599999999999996
# 0.07599999999999996
# 0.07599999999999996
# 0.07599999999999996
# 0.07599999999999996
# 0.07599999999999996
# 0.07599999999999996
# Retraining end...

# %%
from matplotlib import pyplot as plt
plt.plot(range(0, len(error_rate_list2)*2000, 2000), error_rate_list2, label='training=100')
plt.plot(range(0, len(error_rate_list3)*2000, 2000), error_rate_list3, label='training=500')
plt.plot(range(0, len(error_rate_list)*2000, 2000), error_rate_list, label='training=1000')

plt.title('Error Rate in Spam Emails dataset')
plt.xlabel('Fine tuning words')
plt.ylabel('Error Rate')
plt.legend()
plt.show()

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v3_progress
error_rate_list2 = NB_relevant_NB_retraining_v3_progress('task_a_labeled_train.tf', 4000, 0, 'task_a_labeled_tune.tf', 1000, 1500)
# Out:
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.11333333333333329
# 0.08533333333333337
# 0.08133333333333337
# 0.07399999999999995
# 0.07199999999999995
# 0.06866666666666665
# 0.07133333333333336
# 0.07866666666666666
# 0.08066666666666666
# 0.07666666666666666
# 0.07666666666666666
# 0.07799999999999996
# 0.07799999999999996
# 0.07999999999999996
# 0.07866666666666666
# 0.07599999999999996
# 0.07599999999999996
# 0.07666666666666666
# 0.07666666666666666
# 0.07533333333333336
# 0.07266666666666666
# 0.07266666666666666
# 0.07266666666666666
# 0.07266666666666666
# 0.07266666666666666
# 0.07266666666666666
# 0.07266666666666666
# 0.07266666666666666
# 0.07266666666666666
# 0.07266666666666666
# 0.07266666666666666
# 0.07266666666666666
# Retraining end...

# %%
error_rate_list = [0.44733333333333336,
 0.048666666666666636,
 0.04733333333333334,
 0.043333333333333335,
 0.04800000000000004,
 0.050000000000000044,
 0.050000000000000044,
 0.05266666666666664,
 0.05666666666666664,
 0.062000000000000055,
 0.06266666666666665,
 0.06066666666666665,
 0.06066666666666665,
 0.06000000000000005,
 0.06399999999999995,
 0.06799999999999995,
 0.07266666666666666,
 0.06333333333333335,
 0.06333333333333335,
 0.06466666666666665,
 0.06599999999999995,
 0.058666666666666645,
 0.055333333333333345,
 0.055333333333333345,
 0.055333333333333345,
 0.055333333333333345,
 0.055333333333333345,
 0.055333333333333345,
 0.055333333333333345,
 0.055333333333333345,
 0.055333333333333345,
 0.055333333333333345,
 0.055333333333333345]

# %%
from matplotlib import pyplot as plt
plt.plot(range(0, len(error_rate_list)*2000, 2000), error_rate_list, label='uniformaly distributed')
plt.plot(range(0, len(error_rate_list2)*2000, 2000), error_rate_list2, label='skewed')

plt.title('Error Rate in Spam Emails dataset')
plt.xlabel('Fine tuning words')
plt.ylabel('Error Rate')
plt.legend()
plt.show()

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v3
NB_relevant_NB_retraining_v3('task_a_labeled_train.tf', 4000, 0, 'task_a_labeled_tune.tf', 1000, 100)
# Out:
# Pre-model is built
# Target-model is built
# 8073
# 55003
# accuracy(no_transfer):  0.96
# accuracy(directly_transfer):  0.54
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.96
# (0.96, 0.54, 0.96)

# %%
from NB_Relevance_amazon import NB_relevant_NB_retraining_v5_fs_3

origin_accuracy = []

# %%
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5_fs_3('Toys_and_Games.json.gz', 10000, 0, 'Patio_Lawn_and_Garden.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)

accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5_fs_3('Video_Games.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
# Out:
# Pre-model is built
# Target-model is built
# 4344
# 8296
# accuracy(no_transfer):  0.769
# accuracy(directly_transfer):  0.6804
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.6676
# Pre-model is built
# Target-model is built
# 5197
# 9891
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.882
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.8986

# %%
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5_fs_3('Electronics.json.gz', 10000, 0, 'Toys_and_Games.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)

accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5_fs_3('Software.json.gz', 10000, 0, 'Video_Games.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)
# Out:
# Pre-model is built
# Target-model is built
# 4866
# 9524
# accuracy(no_transfer):  0.9192
# accuracy(directly_transfer):  0.8528
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.8694
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-56b58c6401ff> in <module>
#       2 origin_accuracy.append(accuracy_relevant_transfer)
#       3
# ----> 4 accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5_fs_3('Software.json.gz', 10000, 0, 'Video_Games.json.gz', 5000, 5000)
#       5 origin_accuracy.append(accuracy_relevant_transfer)
#
# c:\Users\rando\OneDrive\Working\transfer learning\NB_Relevance_amazon.py in NB_relevant_NB_retraining_v5_fs_3(training_filename, training_size, testing_size, training_filename_transfer, training_size_transfer, testing_size_transfer)
# ...

# %%
accuracy_original, accuracy_transfer, accuracy_relevant_transfer = NB_relevant_NB_retraining_v5_fs_3('Toys_and_Games.json.gz', 10000, 0, 'Software.json.gz', 5000, 5000)
origin_accuracy.append(accuracy_relevant_transfer)

# %%
from NB_Relevance import NB_relevant_NB_retraining_v5_progress
error_rate_list2 = NB_relevant_NB_retraining_v5_progress("./20news-18828/comp.os.ms-windows.misc", "./20news-18828/comp.sys.ibm.pc.hardware", 1200, 0, "./20news-18828/comp.windows.x", "./20news-18828/comp.sys.mac.hardware", 800, 400)
# Out:
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.1875
# 0.12250000000000005
# 0.11750000000000005
# 0.11499999999999999
# 0.10750000000000004
# 0.07499999999999996
# 0.07499999999999996
# 0.07750000000000001
# 0.07750000000000001
# 0.07999999999999996
# 0.07750000000000001
# 0.07750000000000001
# 0.07750000000000001
# 0.07750000000000001
# 0.07750000000000001
# 0.07499999999999996
# 0.0675
# 0.06000000000000005
# 0.05500000000000005
# 0.05249999999999999
# 0.05249999999999999
# 0.05249999999999999
# 0.05249999999999999
# 0.05249999999999999
# 0.05249999999999999
# Retraining end...

# %%
error_rate_list2
# Out:
# [0.49250000000000005,
#  0.4575,
#  0.1875,
#  0.12250000000000005,
#  0.11750000000000005,
#  0.11499999999999999,
#  0.10750000000000004,
#  0.07499999999999996,
#  0.07499999999999996,
#  0.07750000000000001,
#  0.07750000000000001,
#  0.07999999999999996,
#  0.07750000000000001,
#  0.07750000000000001,
#  0.07750000000000001,
#  0.07750000000000001,
#  0.07750000000000001,
#  0.07499999999999996,
#  0.0675,
#  0.06000000000000005,
#  0.05500000000000005,
#  0.05249999999999999,
#  0.05249999999999999,
#  0.05249999999999999,
#  0.05249999999999999,
#  0.05249999999999999,
#  0.05249999999999999]

# %%
from NB_Relevance import NB_relevant_NB_retraining_v5_progress
error_rate_list9 = NB_relevant_NB_retraining_v5_progress("./20news-18828/talk.politics.guns", "./20news-18828/talk.politics.mideast", 1200, 0, "./20news-18828/comp.graphics", "./20news-18828/comp.sys.ibm.pc.hardware", 800, 400)
# Out:
# Pre-model is built
# Target-model is built
# Retraining start...
# 0.18000000000000005
# 0.14
# 0.13
# 0.11250000000000004
# 0.11250000000000004
# 0.10750000000000004
# 0.10750000000000004
# 0.10499999999999998
# 0.10250000000000004
# 0.10999999999999999
# 0.10499999999999998
# 0.10999999999999999
# 0.10750000000000004
# 0.10750000000000004
# 0.10750000000000004
# 0.10750000000000004
# 0.10750000000000004
# 0.10750000000000004
# 0.10750000000000004
# Retraining end...

# %%
error_rate_list9
# Out:
# [0.5225,
#  0.255,
#  0.18000000000000005,
#  0.14,
#  0.13,
#  0.11250000000000004,
#  0.11250000000000004,
#  0.10750000000000004,
#  0.10750000000000004,
#  0.10499999999999998,
#  0.10250000000000004,
#  0.10999999999999999,
#  0.10499999999999998,
#  0.10999999999999999,
#  0.10750000000000004,
#  0.10750000000000004,
#  0.10750000000000004,
#  0.10750000000000004,
#  0.10750000000000004,
#  0.10750000000000004,
#  0.10750000000000004]

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v5
NB_relevant_NB_retraining_v5('task_a_labeled_train.tf', 1000, 0, 'task_a_labeled_tune.tf', 1000, 100)
# Out:
# Pre-model is built
# Target-model is built
# 6173
# 46429
# accuracy(no_transfer):  0.96
# accuracy(directly_transfer):  0.53
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.96
# (0.96, 0.53, 0.96)

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v5
NB_relevant_NB_retraining_v5('task_a_labeled_train.tf', 1000, 0, 'task_a_labeled_tune.tf', 100, 100)
# Out:
# Pre-model is built
# Target-model is built
# 2802
# 33553
# accuracy(no_transfer):  0.88
# accuracy(directly_transfer):  0.54
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.89
# (0.88, 0.54, 0.89)

# %%
from NB_Relevance_spam import NB_relevant_NB_retraining_v5
NB_relevant_NB_retraining_v5('task_a_labeled_train.tf', 1000, 0, 'task_a_labeled_tune.tf', 10, 100)
# Out:
# Pre-model is built
# Target-model is built
# 568
# 29503
# accuracy(no_transfer):  0.74
# accuracy(directly_transfer):  0.42
# Retraining start...
# Retraining end...
# accuracy_relevant_transfer:  0.65
# (0.74, 0.42, 0.65)
